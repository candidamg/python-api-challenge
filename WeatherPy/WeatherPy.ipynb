# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 629

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?q="
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}{city}&appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | maitum
# Processing Record 5 of Set 1 | manzhouli
# Processing Record 6 of Set 1 | kaeo
# Processing Record 7 of Set 1 | wanning
# Processing Record 8 of Set 1 | urubicha
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | dhankuta
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | beyneu
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | sorland
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | sobolevo
# Processing Record 21 of Set 1 | novoye atlashevo
# City not found. Skipping...
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | tomatlan
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | kharhial
# Processing Record 29 of Set 1 | kokuy
# Processing Record 30 of Set 1 | burns lake
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | mollendo
# Processing Record 34 of Set 1 | auchi
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | carballo
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 1 | kandrian
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | kungurtug
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | takhatgarh
# Processing Record 0 of Set 2 | cidreira
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | seoul
# Processing Record 3 of Set 2 | donetsk
# Processing Record 4 of Set 2 | mendoza
# Processing Record 5 of Set 2 | ballina
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 2 | zaruma
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | syriam
# Processing Record 12 of Set 2 | kudahuvadhoo
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | tiznit
# Processing Record 15 of Set 2 | qaqortoq
# Processing Record 16 of Set 2 | nizwa
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | ewa beach
# Processing Record 19 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 2 | broken hill
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | tawang
# Processing Record 23 of Set 2 | alta
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | jining
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | opuwo
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | coolum beach
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | kariba
# Processing Record 38 of Set 2 | tucuman
# Processing Record 39 of Set 2 | niquelandia
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | tadpatri
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | de aar
# Processing Record 45 of Set 2 | hudiksvall
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | ust-nera
# Processing Record 49 of Set 2 | awjilah
# Processing Record 0 of Set 3 | avera
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | baglung
# Processing Record 3 of Set 3 | te anau
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | talcahuano
# Processing Record 10 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | zhanakorgan
# Processing Record 13 of Set 3 | sarangani
# Processing Record 14 of Set 3 | great yarmouth
# Processing Record 15 of Set 3 | jacqueville
# Processing Record 16 of Set 3 | herat
# Processing Record 17 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | valvedditturai
# Processing Record 20 of Set 3 | ivnya
# Processing Record 21 of Set 3 | mufumbwe
# Processing Record 22 of Set 3 | port hedland
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | deputatskiy
# Processing Record 25 of Set 3 | mizdah
# Processing Record 26 of Set 3 | severnyy
# Processing Record 27 of Set 3 | mangochi
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | sarkand
# Processing Record 30 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 3 | bozhou
# Processing Record 32 of Set 3 | santa isabel
# Processing Record 33 of Set 3 | toamasina
# Processing Record 34 of Set 3 | guerrero negro
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | hearst
# Processing Record 37 of Set 3 | kimanait
# City not found. Skipping...
# Processing Record 38 of Set 3 | yanam
# Processing Record 39 of Set 3 | ambilobe
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | saraipali
# Processing Record 43 of Set 3 | olmos
# Processing Record 44 of Set 3 | altamont
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | belance
# Processing Record 47 of Set 3 | urfa
# City not found. Skipping...
# Processing Record 48 of Set 3 | gilgit
# Processing Record 49 of Set 3 | oliveira do hospital
# Processing Record 0 of Set 4 | saint-pierre
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | havelock
# Processing Record 3 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | marzuq
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | singaraja
# Processing Record 8 of Set 4 | pitimbu
# Processing Record 9 of Set 4 | thinadhoo
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | varzea alegre
# Processing Record 12 of Set 4 | ulladulla
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | roald
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | mbanza-ngungu
# Processing Record 17 of Set 4 | avarua
# Processing Record 18 of Set 4 | wattegama
# Processing Record 19 of Set 4 | twentynine palms
# Processing Record 20 of Set 4 | chesma
# Processing Record 21 of Set 4 | harper
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | caronport
# Processing Record 24 of Set 4 | cape town
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | saint-joseph
# Processing Record 27 of Set 4 | sechura
# Processing Record 28 of Set 4 | bonthe
# Processing Record 29 of Set 4 | skjervoy
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | belyy yar
# Processing Record 34 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 4 | olinda
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | progreso
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | gayeri
# Processing Record 40 of Set 4 | netarhat
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | adra
# Processing Record 43 of Set 4 | manjacaze
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 4 | praya
# Processing Record 47 of Set 4 | nantucket
# Processing Record 48 of Set 4 | menongue
# Processing Record 49 of Set 4 | kashan
# Processing Record 0 of Set 5 | naron
# Processing Record 1 of Set 5 | christchurch
# Processing Record 2 of Set 5 | sistranda
# Processing Record 3 of Set 5 | burnie
# Processing Record 4 of Set 5 | sembe
# Processing Record 5 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 5 | sambava
# Processing Record 7 of Set 5 | tolaga bay
# Processing Record 8 of Set 5 | alangayam
# Processing Record 9 of Set 5 | severo-kurilsk
# Processing Record 10 of Set 5 | ilam
# Processing Record 11 of Set 5 | roblin
# Processing Record 12 of Set 5 | takoradi
# Processing Record 13 of Set 5 | pampa
# Processing Record 14 of Set 5 | grindavik
# Processing Record 15 of Set 5 | yalta
# Processing Record 16 of Set 5 | riyadh
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | gallup
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | yarada
# Processing Record 22 of Set 5 | upata
# Processing Record 23 of Set 5 | fort nelson
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | dingle
# Processing Record 26 of Set 5 | rocha
# Processing Record 27 of Set 5 | zhezkazgan
# Processing Record 28 of Set 5 | half moon bay
# Processing Record 29 of Set 5 | tarusan
# Processing Record 30 of Set 5 | umm lajj
# Processing Record 31 of Set 5 | aguimes
# Processing Record 32 of Set 5 | ranong
# Processing Record 33 of Set 5 | ankang
# Processing Record 34 of Set 5 | monrovia
# Processing Record 35 of Set 5 | ginir
# Processing Record 36 of Set 5 | lesosibirsk
# Processing Record 37 of Set 5 | sabha
# Processing Record 38 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | neiafu
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | abu dhabi
# Processing Record 43 of Set 5 | anloga
# Processing Record 44 of Set 5 | humaita
# Processing Record 45 of Set 5 | mahon
# Processing Record 46 of Set 5 | elmira
# Processing Record 47 of Set 5 | birao
# Processing Record 48 of Set 5 | talnakh
# Processing Record 49 of Set 5 | vestmannaeyjar
# Processing Record 0 of Set 6 | san juan de uraba
# Processing Record 1 of Set 6 | khiv
# Processing Record 2 of Set 6 | tukrah
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | fairbanks
# Processing Record 5 of Set 6 | altay
# Processing Record 6 of Set 6 | hay river
# Processing Record 7 of Set 6 | port elizabeth
# Processing Record 8 of Set 6 | veraval
# Processing Record 9 of Set 6 | gamba
# Processing Record 10 of Set 6 | chiredzi
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 6 | salem
# Processing Record 14 of Set 6 | gemena
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | barguzin
# Processing Record 17 of Set 6 | pascagoula
# Processing Record 18 of Set 6 | arantangi
# Processing Record 19 of Set 6 | filingue
# Processing Record 20 of Set 6 | korem
# Processing Record 21 of Set 6 | kirakira
# Processing Record 22 of Set 6 | toora-khem
# Processing Record 23 of Set 6 | arawa
# Processing Record 24 of Set 6 | lovozero
# Processing Record 25 of Set 6 | madison
# Processing Record 26 of Set 6 | airai
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 6 | grande prairie
# Processing Record 29 of Set 6 | trincomalee
# Processing Record 30 of Set 6 | stabat
# Processing Record 31 of Set 6 | kurilsk
# Processing Record 32 of Set 6 | raudeberg
# Processing Record 33 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 6 | ca mau
# Processing Record 35 of Set 6 | zanjan
# Processing Record 36 of Set 6 | dovers
# Processing Record 37 of Set 6 | morgan city
# Processing Record 38 of Set 6 | tiksi
# Processing Record 39 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 6 | njeru
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | newport
# Processing Record 43 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | tigzirt
# Processing Record 46 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 6 | bairiki
# Processing Record 48 of Set 6 | quatre cocos
# Processing Record 49 of Set 6 | erenhot
# Processing Record 0 of Set 7 | sept-iles
# Processing Record 1 of Set 7 | bodden town
# Processing Record 2 of Set 7 | koslan
# Processing Record 3 of Set 7 | powell river
# Processing Record 4 of Set 7 | salalah
# Processing Record 5 of Set 7 | manaus
# Processing Record 6 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 7 | melo
# Processing Record 8 of Set 7 | yumen
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | arraial do cabo
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | belaya gora
# Processing Record 13 of Set 7 | oriximina
# Processing Record 14 of Set 7 | san quintin
# Processing Record 15 of Set 7 | rossland
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | bedford
# Processing Record 19 of Set 7 | shu
# Processing Record 20 of Set 7 | ritchie
# Processing Record 21 of Set 7 | janakpur road
# City not found. Skipping...
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | inhambane
# Processing Record 24 of Set 7 | tuatapere
# Processing Record 25 of Set 7 | vestmanna
# Processing Record 26 of Set 7 | guanica
# Processing Record 27 of Set 7 | port lincoln
# Processing Record 28 of Set 7 | nemuro
# Processing Record 29 of Set 7 | chapais
# Processing Record 30 of Set 7 | oranjemund
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | saint-denis
# Processing Record 33 of Set 7 | curuguaty
# Processing Record 34 of Set 7 | mazatlan
# Processing Record 35 of Set 7 | talara
# Processing Record 36 of Set 7 | sioux lookout
# Processing Record 37 of Set 7 | vredendal
# Processing Record 38 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | bambous virieux
# Processing Record 41 of Set 7 | mongo
# Processing Record 42 of Set 7 | teneguiban
# City not found. Skipping...
# Processing Record 43 of Set 7 | northam
# Processing Record 44 of Set 7 | andreyevo
# Processing Record 45 of Set 7 | haines junction
# Processing Record 46 of Set 7 | dunedin
# Processing Record 47 of Set 7 | soria
# Processing Record 48 of Set 7 | poddorye
# Processing Record 49 of Set 7 | briancon
# Processing Record 0 of Set 8 | haimen
# Processing Record 1 of Set 8 | nuuk
# Processing Record 2 of Set 8 | natchez
# Processing Record 3 of Set 8 | tommot
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | palatka
# Processing Record 6 of Set 8 | palmerston
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | bilibino
# Processing Record 9 of Set 8 | ribeira grande
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | buchanan
# Processing Record 12 of Set 8 | los llanos de aridane
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | brewster
# Processing Record 15 of Set 8 | kitahiroshima
# Processing Record 16 of Set 8 | arlit
# Processing Record 17 of Set 8 | codajas
# Processing Record 18 of Set 8 | burica
# City not found. Skipping...
# Processing Record 19 of Set 8 | nichinan
# Processing Record 20 of Set 8 | usevya
# Processing Record 21 of Set 8 | berbera
# Processing Record 22 of Set 8 | conway
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | puerto del rosario
# Processing Record 25 of Set 8 | kaitangata
# Processing Record 26 of Set 8 | honiara
# Processing Record 27 of Set 8 | shaoyang
# Processing Record 28 of Set 8 | san jose
# Processing Record 29 of Set 8 | taltal
# Processing Record 30 of Set 8 | sitka
# Processing Record 31 of Set 8 | kavieng
# Processing Record 32 of Set 8 | gogrial
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | pingyi
# Processing Record 35 of Set 8 | leghorn
# City not found. Skipping...
# Processing Record 36 of Set 8 | dongsheng
# Processing Record 37 of Set 8 | coos bay
# Processing Record 38 of Set 8 | chokurdakh
# Processing Record 39 of Set 8 | kapit
# Processing Record 40 of Set 8 | kupang
# Processing Record 41 of Set 8 | sur
# Processing Record 42 of Set 8 | tlahualilo
# City not found. Skipping...
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | port hardy
# Processing Record 45 of Set 8 | coahuayana
# Processing Record 46 of Set 8 | breves
# Processing Record 47 of Set 8 | ciudad del maiz
# Processing Record 48 of Set 8 | makakilo city
# Processing Record 49 of Set 8 | cabo san lucas
# Processing Record 0 of Set 9 | winnipeg
# Processing Record 1 of Set 9 | tezu
# Processing Record 2 of Set 9 | kang
# Processing Record 3 of Set 9 | nanortalik
# Processing Record 4 of Set 9 | launceston
# Processing Record 5 of Set 9 | celestun
# Processing Record 6 of Set 9 | rafai
# Processing Record 7 of Set 9 | alyangula
# Processing Record 8 of Set 9 | ucluelet
# Processing Record 9 of Set 9 | salinas
# Processing Record 10 of Set 9 | zaranj
# Processing Record 11 of Set 9 | maceio
# Processing Record 12 of Set 9 | kasane
# Processing Record 13 of Set 9 | cockburn town
# Processing Record 14 of Set 9 | tateyama
# Processing Record 15 of Set 9 | forrest city
# Processing Record 16 of Set 9 | shubarkuduk
# Processing Record 17 of Set 9 | turukhansk
# Processing Record 18 of Set 9 | sable-sur-sarthe
# Processing Record 19 of Set 9 | aksu
# Processing Record 20 of Set 9 | luanda
# Processing Record 21 of Set 9 | rawson
# Processing Record 22 of Set 9 | meulaboh
# Processing Record 23 of Set 9 | faya
# Processing Record 24 of Set 9 | benjamin hill
# Processing Record 25 of Set 9 | mayahi
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | antalaha
# Processing Record 28 of Set 9 | wukari
# Processing Record 29 of Set 9 | roma
# Processing Record 30 of Set 9 | lazaro cardenas
# Processing Record 31 of Set 9 | chumikan
# Processing Record 32 of Set 9 | aksarka
# Processing Record 33 of Set 9 | batemans bay
# Processing Record 34 of Set 9 | darhan
# Processing Record 35 of Set 9 | atar
# Processing Record 36 of Set 9 | gorkovskoye
# City not found. Skipping...
# Processing Record 37 of Set 9 | buluang
# Processing Record 38 of Set 9 | ust-uda
# Processing Record 39 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 9 | coracao de jesus
# Processing Record 41 of Set 9 | swindon
# Processing Record 42 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 9 | muslyumovo
# Processing Record 44 of Set 9 | novoagansk
# Processing Record 45 of Set 9 | djibo
# Processing Record 46 of Set 9 | montrose
# Processing Record 47 of Set 9 | george
# Processing Record 48 of Set 9 | sirari
# Processing Record 49 of Set 9 | gunnedah
# Processing Record 0 of Set 10 | saint-georges
# Processing Record 1 of Set 10 | depalpur
# Processing Record 2 of Set 10 | beaverlodge
# Processing Record 3 of Set 10 | patti
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | poronaysk
# Processing Record 7 of Set 10 | rio cuarto
# Processing Record 8 of Set 10 | sao francisco de paula
# Processing Record 9 of Set 10 | adrar
# Processing Record 10 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 10 | darnah
# Processing Record 12 of Set 10 | platanos
# Processing Record 13 of Set 10 | turayf
# Processing Record 14 of Set 10 | ilorin
# Processing Record 15 of Set 10 | asau
# Processing Record 16 of Set 10 | bouza
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | hamilton
# Processing Record 19 of Set 10 | manokwari
# Processing Record 20 of Set 10 | zhigansk
# Processing Record 21 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 10 | nagato
# Processing Record 25 of Set 10 | urtenen
# Processing Record 26 of Set 10 | ayan
# Processing Record 27 of Set 10 | xai-xai
# Processing Record 28 of Set 10 | balakhta
# Processing Record 29 of Set 10 | luangwa
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | miami shores
# Processing Record 33 of Set 10 | capitao poco
# Processing Record 34 of Set 10 | fukumitsu
# Processing Record 35 of Set 10 | gorontalo
# Processing Record 36 of Set 10 | jijiga
# Processing Record 37 of Set 10 | bestobe
# Processing Record 38 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 10 | santa rosa
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | pacific grove
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | portland
# Processing Record 44 of Set 10 | kahului
# Processing Record 45 of Set 10 | katangli
# Processing Record 46 of Set 10 | verkhoyansk
# Processing Record 47 of Set 10 | safaga
# Processing Record 48 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 10 | san miguel de cauri
# Processing Record 0 of Set 11 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 1 of Set 11 | gigante
# Processing Record 2 of Set 11 | labrea
# Processing Record 3 of Set 11 | la asuncion
# Processing Record 4 of Set 11 | noumea
# Processing Record 5 of Set 11 | inegol
# Processing Record 6 of Set 11 | port blair
# Processing Record 7 of Set 11 | de-kastri
# Processing Record 8 of Set 11 | qiongshan
# Processing Record 9 of Set 11 | miyako
# Processing Record 10 of Set 11 | zhelyabovka
# Processing Record 11 of Set 11 | luorong
# Processing Record 12 of Set 11 | gisborne
# Processing Record 13 of Set 11 | portoferraio
# Processing Record 14 of Set 11 | zaprudnya
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | abu samrah
# Processing Record 17 of Set 11 | agarakadzor
# Processing Record 18 of Set 11 | tevaitoa
# Processing Record 19 of Set 11 | ponta do sol
# Processing Record 20 of Set 11 | comodoro rivadavia
# Processing Record 21 of Set 11 | kukushtan
# Processing Record 22 of Set 11 | sola
# Processing Record 23 of Set 11 | beysehir
# Processing Record 24 of Set 11 | baghdad
# Processing Record 25 of Set 11 | cascais
# Processing Record 26 of Set 11 | waingapu
# Processing Record 27 of Set 11 | kloulklubed
# Processing Record 28 of Set 11 | othonoi
# City not found. Skipping...
# Processing Record 29 of Set 11 | marawi
# Processing Record 30 of Set 11 | kamina
# Processing Record 31 of Set 11 | derzhavinsk
# Processing Record 32 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 11 | atambua
# Processing Record 34 of Set 11 | santa cruz
# Processing Record 35 of Set 11 | vostok
# Processing Record 36 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 11 | constitucion
# Processing Record 38 of Set 11 | taldan
# Processing Record 39 of Set 11 | yulara
# Processing Record 40 of Set 11 | san antonio
# Processing Record 41 of Set 11 | beringovskiy
# Processing Record 42 of Set 11 | shangrao
# Processing Record 43 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 11 | xghajra
# City not found. Skipping...
# Processing Record 45 of Set 11 | aswan
# Processing Record 46 of Set 11 | tual
# Processing Record 47 of Set 11 | rutland
# Processing Record 48 of Set 11 | irpa irpa
# Processing Record 49 of Set 11 | tura
# Processing Record 0 of Set 12 | caldwell
# Processing Record 1 of Set 12 | bilma
# Processing Record 2 of Set 12 | gaoua
# Processing Record 3 of Set 12 | healdsburg
# Processing Record 4 of Set 12 | oyama
# Processing Record 5 of Set 12 | victoria
# Processing Record 6 of Set 12 | keetmanshoop
# Processing Record 7 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 12 | ialisos
# City not found. Skipping...
# Processing Record 9 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 12 | salair
# Processing Record 11 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 12 of Set 12 | obo
# Processing Record 13 of Set 12 | pouebo
# Processing Record 14 of Set 12 | guadalupe y calvo
# Processing Record 15 of Set 12 | naze
# Processing Record 16 of Set 12 | okuchi
# Processing Record 17 of Set 12 | nizhnyaya omka
# Processing Record 18 of Set 12 | oranjestad
# Processing Record 19 of Set 12 | dudinka
# Processing Record 20 of Set 12 | yuryevets
# Processing Record 21 of Set 12 | roebourne
# Processing Record 22 of Set 12 | nome
# Processing Record 23 of Set 12 | yerbogachen
# Processing Record 24 of Set 12 | arman
# Processing Record 25 of Set 12 | paciran
# Processing Record 26 of Set 12 | vieques
# Processing Record 27 of Set 12 | datong
# Processing Record 28 of Set 12 | olafsvik
# Processing Record 29 of Set 12 | baruun-urt
# Processing Record 30 of Set 12 | korla
# Processing Record 31 of Set 12 | saldanha
# Processing Record 32 of Set 12 | arkhara
# Processing Record 33 of Set 12 | fare
# Processing Record 34 of Set 12 | beloha
# Processing Record 35 of Set 12 | vologda
# Processing Record 36 of Set 12 | igrim
# Processing Record 37 of Set 12 | khani
# Processing Record 38 of Set 12 | azanja
# Processing Record 39 of Set 12 | peleduy
# Processing Record 40 of Set 12 | mae hong son
# Processing Record 41 of Set 12 | bud
# Processing Record 42 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 12 | codrington
# Processing Record 44 of Set 12 | lumberton
# Processing Record 45 of Set 12 | taseyevo
# Processing Record 46 of Set 12 | inirida
# Processing Record 47 of Set 12 | zeya
# Processing Record 48 of Set 12 | carutapera
# Processing Record 49 of Set 12 | barra
# Processing Record 0 of Set 13 | pierre
# Processing Record 1 of Set 13 | gainesville
# Processing Record 2 of Set 13 | strezhevoy
# Processing Record 3 of Set 13 | bubaque
# Processing Record 4 of Set 13 | mason city
# Processing Record 5 of Set 13 | blackwater
# Processing Record 6 of Set 13 | otradnoye
# Processing Record 7 of Set 13 | cape canaveral
# Processing Record 8 of Set 13 | santa cruz de tenerife
# Processing Record 9 of Set 13 | hailey
# Processing Record 10 of Set 13 | campobasso
# Processing Record 11 of Set 13 | woodward
# Processing Record 12 of Set 13 | mindelo
# Processing Record 13 of Set 13 | asyut
# Processing Record 14 of Set 13 | tierralta
# Processing Record 15 of Set 13 | yaransk
# Processing Record 16 of Set 13 | gao
# Processing Record 17 of Set 13 | brae
# Processing Record 18 of Set 13 | lodwar
# Processing Record 19 of Set 13 | panaba
# Processing Record 20 of Set 13 | merritt island
# Processing Record 21 of Set 13 | hovd
# Processing Record 22 of Set 13 | chipinge
# Processing Record 23 of Set 13 | johnson city
# Processing Record 24 of Set 13 | lampari
# Processing Record 25 of Set 13 | mubende
# Processing Record 26 of Set 13 | linden
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | north platte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    rikitea -23.1203 -134.9692     26.04        76           3        6.63
# 1     broome  42.2506  -75.8330      5.47        60         100        3.60
# 2  carnarvon -24.8667  113.6333     28.56        58           0        8.21
# 3     maitum   6.0392  124.4986     29.19        66         100        2.40
# 4  manzhouli  49.6000  117.4333    -16.48        87          16        4.52
#
#   Country        Date
# 0      PF  1675655583
# 1      US  1675655584
# 2      AU  1675655491
# 3      PH  1675655585
# 4      CN  1675655586

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          rikitea -23.1203 -134.9692     26.04        76           3
# 1           broome  42.2506  -75.8330      5.47        60         100
# 2        carnarvon -24.8667  113.6333     28.56        58           0
# 3           maitum   6.0392  124.4986     29.19        66         100
# 4        manzhouli  49.6000  117.4333    -16.48        87          16
#
#          Wind Speed Country        Date
# City_ID
# 0              6.63      PF  1675655583
# 1              3.60      US  1675655584
# 2              8.21      AU  1675655491
# 3              2.40      PH  1675655585
# 4              4.52      CN  1675655586

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
date = pd.to_datetime(city_data_df["Date"][0],unit="s").date() #to get the date formated
plt.grid(True)
plt.title(f'City Max Latitude vs. Temperature ({date})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Save the figure
plt.savefig("output_data/LatitudeVSTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
date = pd.to_datetime(city_data_df["Date"][0],unit="s").date() #to get the date formated
plt.grid(True)
plt.title(f'City Latitude vs. Humidity ({date})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
date = pd.to_datetime(city_data_df["Date"][0],unit="s").date() #to get the date formated
plt.grid(True)
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("output_data/LatitudeVSCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')

# Incorporate the other graph properties
date = pd.to_datetime(city_data_df["Date"][0],unit="s").date() #to get the date formated
plt.grid(True)
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Save the figure
plt.savefig("output_data/LatitudeVSWindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots   
def linear_regression(x_values, y_values, title, y_label, val1, val2):
    plt.scatter(x_values,y_values)
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel('Latitude')
    plt.grid(True)
  
    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
   
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(val1,val2),fontsize=15,color="red")

    # Print r value
    print(f"The r-value is: {rvalue**2}")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1     broome  42.2506  -75.8330      5.47        60         100        3.60
# 3     maitum   6.0392  124.4986     29.19        66         100        2.40
# 4  manzhouli  49.6000  117.4333    -16.48        87          16        4.52
# 6    wanning  18.8003  110.3967     25.94        68          85        2.46
# 9   dhankuta  26.9833   87.3333     17.13        45           1        1.47
#
#   Country        Date
# 1      US  1675655584
# 3      PH  1675655585
# 4      CN  1675655586
# 6      CN  1675655586
# 9      NP  1675655582

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        rikitea -23.1203 -134.9692     26.04        76           3
# 2      carnarvon -24.8667  113.6333     28.56        58           0
# 5           kaeo -35.1000  173.7833     20.26        92         100
# 7       urubicha -15.3833  -62.9500     19.97        99          95
# 8  mar del plata -38.0023  -57.5575     24.49        72           0
#
#    Wind Speed Country        Date
# 0        6.63      PF  1675655583
# 2        8.21      AU  1675655491
# 5        2.73      NZ  1675655586
# 7        0.49      BO  1675655587
# 8        3.60      AR  1675655386

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
title = 'Northern Hemisphere = Latitude vs. Temperature'
y_label = 'Max Temperature (C)'
val1 = 0
val2 = -30

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.7678682148358669

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
title = 'Southern Hemisphere = Latitude vs. Temperature'
y_label = 'Max Temperature (C)'
val1 = -30
val2 = 10

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.1112080364466988

# %% [markdown]
# **Discussion about the linear relationship:**
# In the Northern Hemisphere we can see that as the latitute increases the temperature decreases.
# However, in the Southern Hemisphere, whenever the latitue increases, even from -50 to 0, the temperature increases significantly from 10 to 40 as we can see in the graph.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
title = 'Northern Hemisphere = Latitude vs. Humidity'
y_label = 'Humidity (%)'
val1 = 46
val2 = 25

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.18709869333591703

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
title = 'Southern Hemisphere = Latitude vs. Humidity'
y_label = 'Humidity (%)'
val1 = -55
val2 = 10

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.10833689801363454

# %% [markdown]
# **Discussion about the linear relationship:**
# In the latitue vs. humidity for both southern and northern hemispheres, we can see the r-values have a difference of 0.08. At the moment this code was ran, even though, the differencce is for approximately 0.08, there are more information/points in the northern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
title = 'Northern Hemisphere = Latitude vs. Cloudiness'
y_label = 'Cloudiness (%)'
val1 = 46
val2 = 47

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.0715672084665127

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
title = 'Southern Hemisphere = Latitude vs. Cloudiness'
y_label = 'Cloudiness (%)'
val1 = -48
val2 = 22

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.12553310423707115

# %% [markdown]
# **Discussion about the linear relationship:**
# At this moment, the cloudiness percentage is less in the Southern Hemisphere, even with a latitude of -50. However, the Northern Hemisphere a 20% increase in cloudiness and increasing from a 10 latitude and up to 80.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
title = 'Northern Hemisphere = Latitude vs. Wind Speed'
y_label = 'Wind Speed (m/s)'
val1 = 5
val2 = 13

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.008013853295842607

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
title = 'Southern Hemisphere = Latitude vs. Wind Speed'
y_label = 'Wind Speed (m/s)'
val1 = -50
val2 = 9

#calling the function
linear_regression(x_values, y_values, title, y_label, val1, val2)
# Out:
# The r-value is: 0.0823156258181751

# %% [markdown]
# **Discussion about the linear relationship:**
# At this moment, the wind speed is higher in the Northern Hemisphere. The velocity decreases in the Southern Hemisphere even from -50 to 0, whether in the Northern Hemisphere the velocity had a slightly change from 3 to 4 m/s between the 10-80 latitude.
